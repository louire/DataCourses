# %% [markdown]
# <a href="https://colab.research.google.com/github/louire/DataCourses/blob/main/HojaIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
workbookHojas = "/IAHojas.csv"

# %%
df = pd.read_csv(workbookHojas)

# %%
print(df.head())
# Out:
#    Largo  Ancho           Clase
# 0  10.16   5.08  Arbol de Limon
# 1  11.43   5.08  Arbol de Limon
# 2  11.43   5.08  Arbol de Limon
# 3  10.16   5.08  Arbol de Limon
# 4   7.62   5.08  Arbol de Limon

# %%
val = df[["Largo","Ancho","Clase"]]

# %%
meanLargo = val['Largo'].mean()
meanAncho = val['Ancho'].mean()

# %%
val.mean()
# Out:
# <ipython-input-78-66fe5b2a9728>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   val.mean()
# Largo    8.51775
# Ancho    4.33675
# dtype: float64

# %%
ax = val.plot.scatter(x='Largo', y='Ancho', c='teal')

# %%
ax2 = plt.scatter(meanLargo, meanAncho, c="red")
